# %%
import pandas as pd

# %%
df = pd.read_csv("output.csv")

# %%
df
# Out:
#        Point ID      area  Points_0  Points_1  Points_2  Points_Magnitude  \
# 0             0  0.000017  0.215189  0.727280         0          0.758447
# 1             1  0.000017  0.044883 -0.718434         0          0.719835
# 2             2  0.000017  0.145894  0.380212         0          0.407242
# 3             3  0.000017 -0.062413 -0.336682         0          0.342418
# 4             4  0.000017  0.391773 -0.809414         0          0.899243
# ...         ...       ...       ...       ...       ...               ...
# 99995     99995  0.000017  0.286804 -0.535778         0          0.607713
# 99996     99996  0.000017  0.036547  0.382950         0          0.384690
# 99997     99997  0.000017  0.418259  0.785678         0          0.890073
# 99998     99998  0.000017 -0.323319 -0.567759         0          0.653365
# 99999     99999  0.000017 -0.041514 -0.281552         0          0.284596
#
#             sdf  sigma_hoop  sigma_xx  sigma_xy  sigma_yy         u         v
# ...

# %%
df.columns
# Out:
# Index(['Point ID', 'area', 'Points_0', 'Points_1', 'Points_2',
#        'Points_Magnitude', 'sdf', 'sigma_hoop', 'sigma_xx', 'sigma_xy',
#        'sigma_yy', 'u', 'v'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
fig, ax = plt.subplots(figsize = (9,12))

scatter = ax.scatter(df['Points_0'],df['Points_1'], c=df['sigma_xx'],cmap='rainbow', marker='o', s=13)

ax.set_xlabel('x_axis')
ax.set_ylabel('y_axis')

fig.colorbar(scatter, ax=ax, label= 'sigma_xx')

# %%
fig, ax = plt.subplots(figsize = (9,12))

scatter = ax.scatter(df['Points_0'],df['Points_1'], c=df['sigma_yy'],cmap='rainbow', marker='o', s=13)

ax.set_xlabel('x_axis')
ax.set_ylabel('y_axis')

fig.colorbar(scatter, ax=ax, label= 'sigma_yy')

# %%
fig, ax = plt.subplots(figsize = (9,12))

scatter = ax.scatter(df['Points_0'],df['Points_1'], c=df['v'],cmap='rainbow', marker='o', s=13)

ax.set_xlabel('x_axis')
ax.set_ylabel('y_axis')

fig.colorbar(scatter, ax=ax, label= 'v')
